# %% [markdown]
# # Dogecoin Historical Data
#
# #### Introduction
# - Dogecoin is an open source peer-to-peer digital currency, favored by Shiba Inus worldwide. It is qualitatively more fun while being technically nearly identical to its close relative Bitcoin. This dataset contains its historical stock price in USD on a daily frequency starting from 17 September 2014.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('ggplot')

# %%
df=pd.read_csv('DOGE-USD.csv') # importing file 
df.head()
# Out:
#          Date      Open      High       Low     Close   Volume
# 0  2017-11-09  0.001207  0.001415  0.001181  0.001415  6259550
# 1  2017-11-10  0.001421  0.001431  0.001125  0.001163  4246520
# 2  2017-11-11  0.001146  0.001257  0.001141  0.001201  2231080
# 3  2017-11-12  0.001189  0.001210  0.001002  0.001038  3288960
# 4  2017-11-13  0.001046  0.001212  0.001019  0.001211  2481270

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1532 entries, 0 to 1531
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1532 non-null   object
#  1   Open    1532 non-null   float64
#  2   High    1532 non-null   float64
#  3   Low     1532 non-null   float64
#  4   Close   1532 non-null   float64
#  5   Volume  1532 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 71.9+ KB

# %%
df.isnull().sum() # checking for null values
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.describe() # statistical overview of data set
# Out:
#               Open         High          Low        Close        Volume
# count  1532.000000  1532.000000  1532.000000  1532.000000  1.532000e+03
# mean      0.053032     0.056574     0.049593     0.053151  1.049954e+09
# std       0.106257     0.114770     0.097944     0.106358  3.809881e+09
# min       0.001046     0.001210     0.001002     0.001038  1.431720e+06
# 25%       0.002494     0.002551     0.002430     0.002495  1.965492e+07
# 50%       0.003161     0.003260     0.003059     0.003162  6.806869e+07
# 75%       0.009115     0.009615     0.008515     0.009195  2.837324e+08
# max       0.687801     0.737567     0.608168     0.684777  6.941068e+10

# %%
df['Date'] = pd.to_datetime(df['Date'], format="%Y-%m-%d") # changing data type of date column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1532 entries, 0 to 1531
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1532 non-null   datetime64[ns]
#  1   Open    1532 non-null   float64
#  2   High    1532 non-null   float64
#  3   Low     1532 non-null   float64
#  4   Close   1532 non-null   float64
#  5   Volume  1532 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 71.9 KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(6,4),dpi=300)
sns.lineplot(df.Low,df.Volume)
# Out:
# C:\Users\PRATIK GAIKWAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low', ylabel='Volume'>

# %%
plt.figure(figsize=(6,4),dpi=300)
sns.lineplot(df.Open,df.Close)
# Out:
# C:\Users\PRATIK GAIKWAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
plt.figure(figsize=(6,4),dpi=200)
plt.boxplot(df.Open)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db1b1d43a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1db1b1d4ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1db1b1c8fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db1b1e0220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db1b1e05b0>],
#  'means': []}

# %%
plt.figure(figsize=(6,4),dpi=200)
plt.boxplot(df.Close)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db1b245460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1db1b245b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1db1b2450d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db1b24f2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db1b24f670>],
#  'means': []}

# %%
plt.figure(figsize = (18,6), dpi = 200)

plt.subplot(1,3,1)
sns.boxplot(y = 'Open', data = df)

plt.subplot(1,3,2)
sns.boxplot(y = 'Close', data = df)

plt.subplot(1,3,3)
sns.boxplot(y = 'Volume', data = df)
# Out:
# <AxesSubplot:ylabel='Volume'>

# %%
data=df.drop(['Date','Volume'],axis=1) # drop Date and Volume column from data set

# %%
data.head()
# Out:
#        Open      High       Low     Close
# 0  0.001207  0.001415  0.001181  0.001415
# 1  0.001421  0.001431  0.001125  0.001163
# 2  0.001146  0.001257  0.001141  0.001201
# 3  0.001189  0.001210  0.001002  0.001038
# 4  0.001046  0.001212  0.001019  0.001211

# %% [markdown]
# ## Spliting test data and train data

# %% [markdown]
# ## Building of linear regression model to predit close price for given open , high , low prices for a day

# %%
x=data.drop(['Close'],axis=1)

# %%
x
# Out:
#           Open      High       Low
# 0     0.001207  0.001415  0.001181
# 1     0.001421  0.001431  0.001125
# 2     0.001146  0.001257  0.001141
# 3     0.001189  0.001210  0.001002
# 4     0.001046  0.001212  0.001019
# ...        ...       ...       ...
# 1527  0.172053  0.203232  0.171283
# 1528  0.183644  0.193600  0.182676
# 1529  0.185093  0.185093  0.175327
# 1530  0.177187  0.177872  0.166891
# 1531  0.171080  0.173651  0.165412
#
# [1532 rows x 3 columns]

# %%
y=data.Close

# %%
y
# Out:
# 0       0.001415
# 1       0.001163
# 2       0.001201
# 3       0.001038
# 4       0.001211
#           ...
# 1527    0.183549
# 1528    0.185103
# 1529    0.177176
# 1530    0.171145
# 1531    0.166144
# Name: Close, Length: 1532, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
print('Independent feature Shape : ', x.shape)
print('Dependent  feature  Shape : ', y.shape)
# Out:
# Independent feature Shape :  (1532, 3)
# Dependent  feature  Shape :  (1532,)

# %%
print('Training Data Shape    : ', x_train.shape)
print('Training Labels Shape  : ', y_train.shape)
print('Testing Data Shape     : ', x_test.shape)
print('Testing Labels Shape   : ', y_test.shape)
# Out:
# Training Data Shape    :  (1225, 3)
# Training Labels Shape  :  (1225,)
# Testing Data Shape     :  (307, 3)
# Testing Labels Shape   :  (307,)

# %% [markdown]
# ## Training the model

# %%
from sklearn.linear_model import LinearRegression
model =LinearRegression()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.99790623111778

# %%
model.coef_
# Out:
# array([-0.4494159 ,  0.66346613,  0.79702071])

# %%
model.intercept_
# Out:
# -0.00010310063211860926

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
crossValidation=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),x,y,cv=crossValidation)
# Out:
# array([0.99889763, 0.99281854, 0.99562304, 0.99862784, 0.99891074])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.996976
# 1              lasso   -0.005897
# 2      decision_tree    0.992192
#
#                                          best_params
# 0                                {'normalize': True}
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'ran...

# %%
pred_train = model.predict(x_train)
pred_test = model.predict(x_test)

from sklearn.metrics import r2_score
print('Training Data Score : ', r2_score(y_train, pred_train))
print('Testing Data Score  : ', r2_score(y_test, pred_test))
# Out:
# Training Data Score :  0.9978380099785517
# Testing Data Score  :  0.99790623111778

# %% [markdown]
# ## Stochastic Grdient Descent

# %%
from sklearn.linear_model import SGDRegressor
sgd_regressor = SGDRegressor(alpha = 0.001)
sgd_regressor.fit(x_train, y_train)
# Out:
# SGDRegressor(alpha=0.001)

# %%
pred_train = sgd_regressor.predict(x_train)
pred_test = sgd_regressor.predict(x_test)

from sklearn.metrics import r2_score
print('Training Data Score : ', r2_score(y_train, pred_train))
print('Testing Data Score  : ', r2_score(y_test, pred_test))
# Out:
# Training Data Score :  0.49405014488727894
# Testing Data Score  :  0.4803124822396545

# %% [markdown]
# ## Evaluation Metrics

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## checking  mean absolute error for linear regression model

# %%
from sklearn.metrics import mean_absolute_error  
mean_absolute_error(y_test, y_pred)
# Out:
# 0.0017561406476924717

# %% [markdown]
# ## checking  mean_squared_error for linear regression model

# %%
from sklearn.metrics import mean_squared_error 
mean_squared_error(y_test, y_pred)
# Out:
# 2.9591758682301433e-05

# %% [markdown]
# ## checking  Root Mean Squared Error
# - Root of mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred, squared = False)
# Out:
# 0.005439830758608344

# %% [markdown]
# ## checking  R - Squared Score (Coefficient of determination)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.99790623111778

# %% [markdown]
# ### Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model, x,y, cv = 5)
# Out:
# array([0.99025781, 0.99243032, 0.90500177, 0.9960946 , 0.98872481])
